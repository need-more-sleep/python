# %%
import pandas as pd
import os

os.getcwd()
os.chdir("C:/Users\임상현/Desktop\업무/배출체계/181127_주행거리_재작업")
os.getcwd()
os.listdir(".")
# Out:
# ['kt_rawdata',
#  'kt_rawdata.zip',
#  'output_1.csv',
#  'output_2.csv',
#  'TS배출 표준코드.xlsx',
#  '주행거리연산_결과파일양식1.xlsx',
#  '주행거리연산_결과파일양식2.xlsx',
#  '주행거리연산_설명서(2).hwp',
#  '주행거리연산_작업예시(2).xlsx']

# %%
df=pd.read_csv("output_1.csv",encoding='utf-8')
ddf=pd.read_csv("output_2.csv",encoding='utf-8')

# %%
os.getcwd()
os.chdir("C:/Users\임상현/Desktop\업무/배출체계/181127_주행거리_재작업/kt_rawdata")
os.getcwd()
os.listdir(".")

df_2=pd.read_csv("kt_trans2_A.txt",sep='\t',encoding='utf-8')
df_2

ddf_2=pd.read_csv("kt_trans2_B.txt",sep='\t',encoding='utf-8')

# %%
haha = []
ha=[]

ha=ddf.NCODE
haha=df.NCODE

ddf.index=ha
df.index=haha

ddf
# Out:
#              NCODE  Scode1  Bcode  Ccode1  Ccode2  Fcode  Ycode  N_KT   KT
# NCODE
# 10011111  10011111       1      1       1       1      1      1     0  0.0
# 10111111  10111111       1      1       1       1      1      1     0  0.0
# 10211111  10211111       1      1       1       1      1      1     0  0.0
# 10311111  10311111       1      1       1       1      1      1     0  0.0
# 10411111  10411111       1      1       1       1      1      1     0  0.0
# 10511111  10511111       1      1       1       1      1      1     0  0.0
# 10611111  10611111       1      1       1       1      1      1     0  0.0
# 10711111  10711111       1      1       1       1      1      1     0  0.0
# 10811111  10811111       1      1       1       1      1      1     0  0.0
# 10911111  10911111       1      1       1       1      1      1     0  0.0
# 11011111  11011111       1      1       1       1      1      1     0  0.0
# ...

# %%
count=0

while count <= 16490:
    
    a=0
    b=0
    c=0
    
    a=df_2.iloc[count,:].Ncode
    a=int(a)
    
    b=df_2.iloc[count,:].COUNT
    c=df_2.iloc[count,:].Lcode_avg
    
    b=int(b)
    c=float(c)
    
    df.loc[a,'N_KT']=b
    df.loc[a,'KT']=c
    
    count=count+1

# %%
count=0

while count <= 43035:
    
    a=0
    b=0
    c=0
    
    a=ddf_2.iloc[count,:].Ncode
    a=int(a)
    
    b=ddf_2.iloc[count,:].COUNT
    c=ddf_2.iloc[count,:].Lcode_avg
    
    b=int(b)
    c=float(c)
    
    ddf.loc[a,'N_KT']=b
    ddf.loc[a,'KT']=c
    
    count=count+1
    
    
    if count%1000 == 0:
        print(count)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-135-348fe3c4e7f6> in <module>()
#       7     c=0
#       8
# ----> 9     a=ddf_2.iloc[count,:].Ncode
#      10     a=int(a)
#      11
#
# D:\conda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ...

# %%
df.to_csv("out_1.csv")

# %%
ddf.to_csv("out_2.csv")

# %%
import pandas as pd
import os

os.getcwd()
os.chdir("C:/Users/임상현/Desktop/업무/배출체계/181127_주행거리_재작업/kt_rawdata")
os.getcwd()
os.listdir(".")
# Out:
# ['2017자동차주행거리통계_마이크로데이터(개인정보제외) - 복사본.txt',
#  'kt_trans1_1.txt',
#  'kt_trans1_2_new.txt',
#  'kt_trans1_2_old.txt',
#  'kt_trans2_A.txt',
#  'kt_trans2_B.txt',
#  'out_1.csv',
#  'out_2.csv',
#  'text.csv',
#  'text_data.txt',
#  '[배출체계]주행거리_재작업.zip']

# %%
night=pd.read_csv("kt_trans1_2_new.txt",sep=',',encoding='utf-8')
# Out:
# D:\conda\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
night
# Out:
#             Ncode  Scode1  Scode2  Bcode  Ccode1  Ccode2  Fcode  Ocode  Wcode  \
# 0        22223324       1     222      2       3       3      2    4.0      2
# 1        25433324       1     254      3       3       3      2    4.0      2
# 2        16633474       1     166      3       3       4      7    4.0      2
# 3        28621214       1     286      2       1       2      1    4.0      2
# 4        10221414       1     102      2       1       4      1    4.0      2
# 5        17934424       1     179      3       4       4      2    4.0      2
# 6        32923224       1     329      2       3       2      2    4.0      2
# 7        11524324       1     115      2       4       3      2    4.0      2
# 8        32524424       1     325      2       4       4      2    4.0      2
# 9        22521414       1     225      2       1       4      1    4.0      2
# 10       12321414       1     123      2       1       4      1    4.0      2
# ...

# %%
ok1=night.loc[ (night['Fcode']==2) & (night['Ccode1']==3) & (night['Ccode2']==2) & (night['Ocode']==1) ]
ok2=night.loc[ (night['Fcode']==2) & (night['Ccode1']==3) & (night['Ccode2']==2) & (night['Ocode']==2) ]
ok3=night.loc[ (night['Fcode']==2) & (night['Ccode1']==3) & (night['Ccode2']==2) & (night['Ocode']==3) ]
ok4=night.loc[ (night['Fcode']==2) & (night['Ccode1']==3) & (night['Ccode2']==2) & (night['Ocode']==4) ]

ook1=night.loc[ (night['Fcode']==1) & (night['Ccode1']==1) & (night['Ccode2']==3) & (night['Ocode']==1) ]
ook2=night.loc[ (night['Fcode']==1) & (night['Ccode1']==1) & (night['Ccode2']==3) & (night['Ocode']==2) ]
ook3=night.loc[ (night['Fcode']==1) & (night['Ccode1']==1) & (night['Ccode2']==3) & (night['Ocode']==3) ]
ook4=night.loc[ (night['Fcode']==1) & (night['Ccode1']==1) & (night['Ccode2']==3) & (night['Ocode']==4) ]


lok1=night.loc[ (night['Fcode']!=2) & (night['Ccode1']==3) & (night['Ccode2']==2) & (night['Ocode']==1) ]
lok2=night.loc[ (night['Fcode']!=2) & (night['Ccode1']==3) & (night['Ccode2']==2) & (night['Ocode']==2) ]
lok3=night.loc[ (night['Fcode']!=2) & (night['Ccode1']==3) & (night['Ccode2']==2) & (night['Ocode']==3) ]
lok4=night.loc[ (night['Fcode']!=2) & (night['Ccode1']==3) & (night['Ccode2']==2) & (night['Ocode']==4) ]

# %%
ok1.Lcode.to_csv('b1.csv')
ok2.Lcode.to_csv('b2.csv')
ok3.Lcode.to_csv('b3.csv')
ok4.Lcode.to_csv('b4.csv')

ook1.Lcode.to_csv('bb1.csv')
ook2.Lcode.to_csv('bb2.csv')
ook3.Lcode.to_csv('bb3.csv')
ook4.Lcode.to_csv('bb4.csv')

lok1.Lcode.to_csv('bbb1.csv')
lok2.Lcode.to_csv('bbb2.csv')
lok3.Lcode.to_csv('bbb3.csv')
lok4.Lcode.to_csv('bbb4.csv')

# %%
night
# Out:
#          Unnamed: 0     Ncode  Scode1  Scode2  Bcode  Ccode1  Ccode2  Fcode  \
# 0                 0  22223324       1     222      2       3       3      2
# 1                 1  25433324       1     254      3       3       3      2
# 2                 2  16633474       1     166      3       3       4      7
# 3                 3  28621214       1     286      2       1       2      1
# 4                 4  10221414       1     102      2       1       4      1
# 5                 5  17934424       1     179      3       4       4      2
# 6                 6  32923224       1     329      2       3       2      2
# 7                 7  11524324       1     115      2       4       3      2
# 8                 8  32524424       1     325      2       4       4      2
# 9                 9  22521414       1     225      2       1       4      1
# 10               10  12321414       1     123      2       1       4      1
# ...

# %%
mini=[]
middle=[]

mini.append(ok1.Lcode.mean())
mini.append(ok2.Lcode.mean())
mini.append(ok3.Lcode.mean())
mini.append(ok4.Lcode.mean())

middle.append(ook1.Lcode.mean())
middle.append(ook2.Lcode.mean())
middle.append(ook3.Lcode.mean())
middle.append(ook4.Lcode.mean())

# %%
print(mini)
print(middle)
# Out:
# [59.35018976595532, 51.711580965572495, 39.324195820857994, 24.712660518124256]
# [27.6739174213718, 38.90995417191915, 25.217764661507427, 22.41174338647218]

# %%
ok1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cb4abc17723f> in <module>()
# ----> 1 ok1
#
# NameError: name 'ok1' is not defined

# %%
night.loc[ (night['Fcode']==1) & (night['Ccode1']==3) & (night['Ccode2']==3) & (night['Ocode']==1) ]
# Out:
#             Ncode  Scode1  Scode2  Bcode  Ccode1  Ccode2  Fcode  Ocode  Wcode  \
# 21915    11723311       1     117      2       3       3      1    1.0      2
# 21916    21023311       1     210      2       3       3      1    1.0      2
# 21920    39023311       1     390      2       3       3      1    1.0      2
# 21921    35823311       1     358      2       3       3      1    1.0      2
# 25486    26023311       1     260      2       3       3      1    1.0      2
# 5875587  20423311       1     204      2       3       3      1    1.0      2
#
#              Lcode     Mcode      LMcode
# 21915    24.902813  4.464212  111.171426
# 21916    33.542373  4.427557  148.510762
# 21920    70.234450  4.250813  298.553515
# 21921     3.239819  4.116271   13.335973
# 25486     6.403941  4.271611   27.355148
# 5875587  27.720109  4.427557  122.732356
